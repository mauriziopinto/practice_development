# %% [markdown]
# # First machine learning example

# %%
# %matplotlib inline
# Import libraries (Numpy, Tensorflow, matplotlib)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create 1000 points following a function y=0.1 * x + 0.4 (i.e. y = W * x + b) with some normal random distribution:
df = pd.read_csv("./UN.csv")
df = df.dropna()
print(df)
# Out:
#                Unnamed: 0  infant.mortality      gdp
# 0             Afghanistan             154.0   2848.0
# 1                 Albania              32.0    863.0
# 2                 Algeria              44.0   1531.0
# 5                  Angola             124.0    355.0
# 6                 Antigua              24.0   6966.0
# 7               Argentina              22.0   8055.0
# 8                 Armenia              25.0    354.0
# 9               Australia               6.0  20046.0
# 10                Austria               6.0  29006.0
# 11             Azerbaijan              33.0    321.0
# 12                Bahamas              14.0  12545.0
# 13                Bahrain              18.0   9073.0
# 14             Bangladesh              78.0    280.0
# 15               Barbados               9.0   7173.0
# 16                Belarus              15.0    994.0
# 17                Belgium               7.0  26582.0
# 18                 Belize              30.0   2569.0
# 19                  Benin              84.0    391.0
# 20                 Bhutan             104.0    166.0
# 21                Bolivia              66.0    909.0
# 22                 Bosnia              13.0    271.0
# 23               Botswana              56.0   3640.0
# 24                 Brazil              42.0   4510.0
# 25                 Brunei               9.0  16683.0
# 26               Bulgaria              16.0   1518.0
# 27           Burkina.Faso              97.0    165.0
# 28                Burundi             114.0    205.0
# 29               Cambodia             102.0    130.0
# 30               Cameroon              58.0    627.0
# 31                 Canada               6.0  18943.0
# ..                    ...               ...      ...
# 174            St.Vincent              19.0   2305.0
# 175                 Sudan              71.0     36.0
# 176              Suriname              24.0    967.0
# 177             Swaziland              65.0   1389.0
# 178                Sweden               5.0  26253.0
# 179           Switzerland               5.0  42416.0
# 180                 Syria              33.0   3573.0
# 181            Tajikistan              56.0    122.0
# 182              Tanzania              80.0    139.0
# 183              Thailand              30.0   2896.0
# 184                  Togo              86.0    322.0
# 185                 Tonga               3.0   1787.0
# 186   Trinidad.and.Tobago              14.0   4083.0
# 187               Tunisia              37.0   2030.0
# 188                Turkey              44.0   2814.0
# 189          Turkmenistan              57.0    321.0
# 191                Uganda             113.0    305.0
# 192               Ukraine              18.0    694.0
# 193  United.Arab.Emirates              15.0  17690.0
# 194        United.Kingdom               6.0  18913.0
# 195         United.States               7.0  26037.0
# 196               Uruguay              17.0   5602.0
# 197            Uzbekistan              43.0    435.0
# 198               Vanuatu              38.0   1289.0
# 199             Venezuela              21.0   3496.0
# 200              Viet.Nam              37.0    270.0
# 203                 Yemen              80.0    732.0
# 204            Yugoslavia              19.0   1487.0
# 205                Zambia             103.0    382.0
# 206              Zimbabwe              68.0    786.0
#
# [193 rows x 3 columns]

# %%
# Separate the data point across axises

x_data = df['gdp'].values
x_data = np.reshape(x_data,(193,1))

y_data = df['infant.mortality'].values

# %%
# Plot and show the data points in a 2D space
plot.plot(x_data, y_data, 'ro', label='Original data')
plot.legend()
plot.show()

# %%
from sklearn import neighbors

# %%
# Parameters
n_neighbors = 8
weigths = "uniform" #"distance"

# %%
# Define model
neigh = neighbors.KNeighborsRegressor(n_neighbors=2, weights=weigths)

# %%
# Fit regression model
neigh.fit(x_data, y_data)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=1, n_neighbors=2, p=2,
#           weights='uniform')

# %%
# Predict one value
print(neigh.predict([[20]]))
# Out:
# [61.]

# %%
# Predict several examples and plot with original
T = np.linspace(0, 40000, 400)[:, np.newaxis]
ypredict = neigh.predict(T)
plt.figure(figsize=(22,7))
plt.scatter(x_data, y_data, c='r', label='data')
plt.plot(T, ypredict, c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.show()
